# %%
s=open(r"C:\Users\Derek Hart\Documents\Python\rosalind_prot.txt").read()

# %%
data = open(r"C:\Users\Derek Hart\Documents\Python\RNAcodontable.txt").read()
data = data.split('\n')
x = [x.split(' ') for x in data if x] 
rnacodons = []
for n in x: 
    n = [i for i in n if i]
    rnacodons.append(n)
rnacodons = dict(rnacodons)

# %%
protein = ''.join([rnacodons[s[i*3:i*3+3]] for i in range(int(len(s)/3))])

# %%
protein
# Out:
# '...'
